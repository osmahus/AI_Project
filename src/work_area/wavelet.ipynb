# %%
# import os
import pandas as pd
import numpy as np

from helpers.dataset_process import dataset_to_df, search_df
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
from pywt import WaveletPacket2D as wp2d
# import pywt as wp2d
import cv2
from skimage.color import rgb2gray

# %%
path = '../../../data/CIFAK'
relative_paths = ["/train/REAL", "/train/FAKE", "/test/REAL", "/test/FAKE"]
paths_classes = ["REAL", "FAKE", "REAL", "FAKE"]

# for r_path in relative_paths:
#     remove_fname_space(path + r_path)

df_all, df_train, df_val, df_test, classes_stats = dataset_to_df(
    path, relative_paths, paths_classes, 0.8, 0.19, 0.01)

# %%
path2 = '../../../data/meso_data'
relative_paths2= ["/Real", "/DeepFake"]
paths_classes2=['REAL',"FAKE"]


df_all2, df_train2, df_val2, df_test2, classes_stats2 = dataset_to_df(
    path2, relative_paths2, paths_classes2, 0.8, 0.19, 0.01)

# %%
search_df(df_all2,"82_678")
# Out:
# 2937

# %% [markdown]
# System signal processing
# localization of features
# 1) In fourier series , sin wave is the basis function (i.e. it forms a good waveform to represent wide varieties of signals)
# 2) Problem of the sin wave is that lasts forever (from $-\infty$ to $+\infty$)
# 3) wavelets are small waves ( waves that don't last forever)
# 4) The uncertainty in the time and frequency domain
# 5) Analysis vs Representation
# 6) har multi-resolution analysis
# 7) Fourier analysis takes non-smooth signal and analyze it to a some of smooth signals (sin waves) , haar discussed the opposite, by taking a smooth signal and compose it from some of non smooth signals ( which is used when audio is digitized to be stored and transmitted) , this is called haar multi-resolution analysis.
# 8) multi-rate digital processing
# 9) resolution is the ability to identify specific components
# 10) Going down to lower frequencies (signal is slower changing) we need to focus on having better frequency resolution rather than time resolution , hence we can have a slower sampling rate and a larger time intervals.
# On the opposite side, when we go up to higher frequencies (signal becomes very fast changing) we need better time resolution ( i.e we need to narrow down on the time axis to know at which time interval the frequency change happens , hence we need to sample at higher frequency) , to conclude we will use different sampling rate in the same system for the same signal.
# 11) Filter Banks : system of filters which have the a common input or a common output, hence we have an analysis filter banks and a synthesis filter bank.

# %% [markdown]
# Piecewise Constant representation of the image, one constant for each piece(pixel)
# The smaller the pixel area , the higher the resolution

# %% [markdown]
# Mother wavelet $\Psi(t)$ <br>
# Daughter wavelets $\Psi_{a, b}$<br><br>
# where $\Psi_{a, b}=\Psi\left(\frac{t-b}{a}\right)$<br><br>
# and a: is a frequency scale $\Rightarrow$ the higher the a, the lower the frequency<br>
# and b : is a time shift, to the right if b is (+ve) or to the left of b is (-ve) <br>
# to measure the similarity (Amplitude) $T(a, b)$ between the wavelet function and the original signal function $y(t)$ we convolute both functions <br><br>
# $T(a, b)=\int_{-\infty}^{\infty} y(t) \cdot \Psi_{a, b}(t) d t$ <br><br>
# $T(a, b)$ is also referred to as the Continuous Wavelet Transform (CWT) and the result of this transform is called wavelet coefficients
#
# $$
# \begin{aligned}
# & \int_{-\infty}^{\infty} \Psi(t) d t=0 \\
# \end{aligned}
# $$
# This means that the wavelet function has an average of zero
# $$
# \begin{aligned}
# & \int_{-\infty}^{\infty}|\Psi(t)|^2 d t<\infty \\
# & \psi(t)=k_0 \cdot \cos (\omega t) \cdot e^{-\frac{t^2}{2}}
# \end{aligned}
# $$
# $$
# \begin{aligned}
# & \vec{a}=\left[a_1, a_2, \ldots, a_N\right] \\
# & \vec{b}=\left[b_1, b_2, \ldots, b_N\right] \\
# & \vec{a} \cdot \vec{b}=a_1 b_1+a_2 b_2+\ldots+a_N b_N \\
# & \langle f, g\rangle=\int_{-\infty}^{\infty} f(t) g(t) d t \\
# & T(a, b)=\int_{-\infty}^{\infty} y(t) \cdot \Psi_{a, b}(t) d t \\
# & \Psi_{a, b}=\Psi\left(\frac{t-b}{a}\right)
# \end{aligned}
# $$

# %%
print(pywt.families())
print(pywt.wavelist('haar'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(pywt.families())
#       2 print(pywt.wavelist('haar'))
#
# NameError: name 'pywt' is not defined

# %%
discrete_wavelets = ['db5', 'sym5', 'coif5', 'bior2.4']
continuous_wavelets = ['mexh', 'morl', 'cgau5', 'gaus5']

list_list_wavelets = [discrete_wavelets, continuous_wavelets]
list_funcs = [pywt.Wavelet, pywt.ContinuousWavelet]

fig, axarr = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))
for ii, list_wavelets in enumerate(list_list_wavelets):
    func = list_funcs[ii]
    row_no = ii
    for col_no, waveletname in enumerate(list_wavelets):
        wavelet = func(waveletname)
        family_name = wavelet.family_name
        biorthogonal = wavelet.biorthogonal
        orthogonal = wavelet.orthogonal
        symmetry = wavelet.symmetry
        if ii == 0:
            _ = wavelet.wavefun()
            wavelet_function = _[0]
            x_values = _[-1]
        else:
            wavelet_function, x_values = wavelet.wavefun()

        if col_no == 0 and ii == 0:
            axarr[row_no, col_no].set_ylabel("Discrete Wavelets", fontsize=16)
        if col_no == 0 and ii == 1:
            axarr[row_no, col_no].set_ylabel(
                "Continuous Wavelets", fontsize=16)
        axarr[row_no, col_no].set_title("{}".format(family_name), fontsize=16)
        axarr[row_no, col_no].plot(x_values, wavelet_function)
        axarr[row_no, col_no].set_yticks([])
        axarr[row_no, col_no].set_yticklabels([])

plt.tight_layout()
plt.show()
# Out:
# /home/osmahus/pytVenv/lib/python3.11/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/osmahus/pytVenv/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
img = plt.imread(df_all2.iloc[2937, 0])
img_normalized = cv2.normalize(img, None, 0, 1.0, cv2.NORM_MINMAX, dtype=cv2.CV_32F)
img[:,:,0].shape
# Out:
# (352, 352)

# %%
figure = plt.figure(figsize=(4, 2))

mpl.style.use('seaborn-v0_8')
color_palettes = ['gray','viridis','inferno','magma','plasma','jet']
cm = plt.get_cmap(color_palettes[1])
alpha=1

ax1 = plt.subplot(121)
ax1.imshow(img)
ax1.grid(False)
ax1.axis("off")

ax2 = plt.subplot(122)
ax2.imshow(img_normalized[:,:,:])
ax2.grid(False)
ax2.axis("off");

# %%
im_weighted_mean = rgb2gray(img)

plt.imshow(im_weighted_mean, cmap='gray')
plt.axis(False)
plt.show()

# %%
im_weighted_mean.shape
# Out:
# (352, 352)

# %%
img_normalized.shape
# Out:
# (352, 352, 3)

# %%
w2 = 'db2'
wp = pywt.WaveletPacket2D(data=im_weighted_mean, wavelet=w2, mode='symmetric')
# wp['dd'].wavelet.wavefun()[1]

# %%
def wp_decompose(img, wavelet_function, level):
    rows = level**2
    # img_mean = cv2.normalize(img, None, 0, 1.0, cv2.NORM_MINMAX, dtype=cv2.CV_32F)

    img_mean = rgb2gray(img)
    wp = wp2d(data=img_mean, wavelet=wavelet_function, mode='symmetric')
    paths = [node.path for node in wp.get_level(level)]
    nodes = [wp[path].data for path in paths]

    wp_func = wp[paths[0]].wavelet.wavefun()
    wp_name = wp[paths[0]].wavelet.family_name
    x = wp_func[-1]
    y = wp_func[0]
    
    return rows, (x,y), wp_name, paths, nodes

# %%
w2 = 'db2'
level = 2
img = plt.imread(df_all2.iloc[2937, 0])
rows, wp_func, wp_name, paths, nodes = wp_decompose(
    img, wavelet_function, level)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 w2 = 'db2'
#       2 level = 2
# ----> 3 img = plt.imread(df_all2.iloc[2937, 0])
#       4 rows, wp_func, wp_name, paths, nodes = wp_decompose(
#       5     img, wavelet_function, level)
#
# NameError: name 'plt' is not defined

# %%
def plot_wp_nodes(img, wavelet_function, level):
    rows, wp_func, wp_name, paths, nodes = wp_decompose(
        img, wavelet_function, level)
    
    cols=rows

    ax.plot(wp_func)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(wp_name)

    fig = plt.figure(layout="constrained", figsize=(8, 8))
    grid = ImageGrid(fig, 111, nrows_ncols=(rows, cols), axes_pad=0.3)
    nodes = []
    for i, ax in enumerate(grid):
        node = wp[paths[i]].data
        ax.imshow(node)
        # ax.set_grid(False)
        ax.grid(False)
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(paths[i])
        nodes.append(node)




    fig = plt.figure(layout="constrained", figsize=(12, 4))
    subfigs = fig.subfigures(3, 1, height_ratios=[1.2, 1.5, 1.], hspace=0.05, squeeze='True')

    ax= subfigs[0].subplots(1, 1)
    
    ax.imshow(img)
    ax.set_xticks([])
    ax.set_yticks([])

    grid1 = ImageGrid(subfigs[1], 111, nrows_ncols=(rows,cols), axes_pad=0.05)

    for i, ax in enumerate(grid1):
        i = str(np.base_repr(i, len(paths))).zfill(2)
        
        row = int(i_b4[0])
        column = int(i_b4[1])
        
        ax.imshow(patch)
        ax.set_xticks([])
        ax.set_yticks([])

    grid2 = ImageGrid(subfigs[2], 111, nrows_ncols=(1, sliced_img.size(0)*sliced_img.size(1)), axes_pad=0.03)

    for i, ax in enumerate(grid2):
        i_b4 = str(np.base_repr(i, sliced_img.size(0))).zfill(2)
        row = int(i_b4[0])
        column = int(i_b4[1])
        patch = rearrange(sliced_img[row][column], "c h w -> h w c").numpy()
        
        ax.imshow(patch)
        ax.set_xticks([])
        ax.set_yticks([])

# %%
# plot_wavelets(img, w2, level)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 w2 = 'db2'
#       2 level = 2
# ----> 3 img = plt.imread(df_all2.iloc[2937, 0])
#       4 # plot_wavelets(img, w2, level)
#
# NameError: name 'plt' is not defined

# %%
for ii, list_wavelets in enumerate(list_list_wavelets):
    func = list_funcs[ii]
    row_no = ii
    for col_no, waveletname in enumerate(list_wavelets):
        wavelet = func(waveletname)
        family_name = wavelet.family_name
        biorthogonal = wavelet.biorthogonal
        orthogonal = wavelet.orthogonal
        symmetry = wavelet.symmetry
        if ii == 0:
            _ = wavelet.wavefun()
            wavelet_function = _[0]
            x_values = _[-1]
        else:
            wavelet_function, x_values = wavelet.wavefun()

        if col_no == 0 and ii == 0:
            axarr[row_no, col_no].set_ylabel("Discrete Wavelets", fontsize=16)
        if col_no == 0 and ii == 1:
            axarr[row_no, col_no].set_ylabel(
                "Continuous Wavelets", fontsize=16)
        axs[row_no, col_no].set_title("{}".format(family_name), fontsize=16)
        axs[row_no, col_no].plot(x_values, wavelet_function)
        axs[row_no, col_no].set_yticks([])
        axs[row_no, col_no].set_yticklabels([])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 7
#       4 grid1 = ImageGrid(fig, 111, nrows_ncols=(level**2, level**2), axes_pad=0.05)
#       6 for i, ax in enumerate(grid1):
# ----> 7     i_b4 = str(np.base_repr(i, sliced_img.size(0))).zfill(2)
#       8     row = int(i_b4[0])
#       9     column = int(i_b4[1])
#
# NameError: name 'sliced_img' is not defined

# %%
level = 2
print(wp.data.shape)
# print(wp.level)
# print(wp.maxlevel)

path11 = ""
path12 = ""
path21 = ""
path22 = ""
paths = [node.path for node in wp.get_level(level)]
print(len(paths))
for i, path in enumerate(paths):
    if (i+1) % level**2 == 0:
        print(path)
    else:
        print(path, end=' ')  # don't move to new line , and next print
    
    if i == 0: path11 = path
    elif i == level**2-1: path12 = path
    elif i == len(paths)-level**2: path21 = path
    elif i == len(paths)-1: path22 = path

# print("")
# print(path11)
# print(path12)
# print(path21)
# print(path22)
# Out:
# (352, 352)
# 16
# aa ah av ad
# ha hh hv hd
# va vh vv vd
# da dh dv dd

# %%
img_sample1 = np.array(wp[path11].data)
img_sample2 = np.array(wp[path12].data)
img_sample3 = np.array(wp[path21].data)
img_sample4 = np.array(wp[path22].data)

print(img_sample1.shape)
print(img_sample2.shape)
print(img_sample3.shape)
print(img_sample4.shape)

ax1 = plt.subplot(221)
ax1.imshow(img_sample1)
ax1.grid(False)
ax1.axis("off")
ax1 = plt.subplot(222)
ax1.imshow(img_sample2)
ax1.grid(False)
ax1.axis("off")
ax1 = plt.subplot(223)
ax1.imshow(img_sample3)
ax1.grid(False)
ax1.axis("off")
ax1 = plt.subplot(224)
ax1.imshow(img_sample4)
ax1.grid(False)
ax1.axis("off")
# Out:
# (90, 90)
# (90, 90)
# (90, 90)
# (90, 90)
# (-0.5, 89.5, 89.5, -0.5)
